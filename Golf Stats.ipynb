# %%
import requests
from bs4 import BeautifulSoup as BS
import time
import mysql.connector

# %%
def get_driving_stats(year):
    year_list = [2018,2010]
    List_stats = []
    for year in year_list:
        url ='https://www.pgatour.com/content/pgatour/stats/stat.297.y{}.eoff.t020.html'.format(year)
        soup = BS((requests.get(url)).content, 'html.parser')
        page = soup.find('tbody')
        for row in page.find_all('tr'):
            Stats = {}
            name = (row.find('td', class_= 'player-name').get_text())
            name = name.split('\n')
            Stats['Player'] = name[1]
            Stats["Fairway_Streak"] = int(row.find('td', class_= 'player-name').find_next('td').get_text())
            Stats['Year'] = int(url[56:60])
            List_stats.append(Stats)
    return List_stats

get_driving_stats(2016)
# Out:
# [{'Player': 'Jung-gon Hwang', 'Fairway_Streak': 36, 'Year': 2018},
#  {'Player': 'Troy Merritt', 'Fairway_Streak': 34, 'Year': 2018},
#  {'Player': 'Nick Taylor', 'Fairway_Streak': 30, 'Year': 2018},
#  {'Player': 'Chez Reavie', 'Fairway_Streak': 29, 'Year': 2018},
#  {'Player': 'Dicky Pride', 'Fairway_Streak': 29, 'Year': 2018},
#  {'Player': 'Byeong Hun An', 'Fairway_Streak': 28, 'Year': 2018},
#  {'Player': 'Morgan Hoffmann', 'Fairway_Streak': 28, 'Year': 2018},
#  {'Player': 'Jim Furyk', 'Fairway_Streak': 28, 'Year': 2018},
#  {'Player': 'Fabián Gómez', 'Fairway_Streak': 27, 'Year': 2018},
#  {'Player': 'Hideki Matsuyama', 'Fairway_Streak': 26, 'Year': 2018},
#  {'Player': 'Tyler Duncan', 'Fairway_Streak': 25, 'Year': 2018},
#  {'Player': 'C.T. Pan', 'Fairway_Streak': 25, 'Year': 2018},
#  {'Player': 'Ben Crane', 'Fairway_Streak': 25, 'Year': 2018},
#  {'Player': 'Sam Ryder', 'Fairway_Streak': 23, 'Year': 2018},
#  {'Player': 'Ken Duke', 'Fairway_Streak': 23, 'Year': 2018},
#  {'Player': 'K.J. Choi', 'Fairway_Streak': 22, 'Year': 2018},
#  {'Player': 'Joel Dahmen', 'Fairway_Streak': 21, 'Year': 2018},
#  {'Player': 'Anirban Lahiri', 'Fairway_Streak': 21, 'Year': 2018},
#  {'Player': 'Jamie Lovemark', 'Fairway_Streak': 21, 'Year': 2018},
#  {'Player': 'Prayad Marksaeng', 'Fairway_Streak': 21, 'Year': 2018},
#  {'Player': 'Keegan Bradley', 'Fairway_Streak': 20, 'Year': 2018},
#  {'Player': 'Xinjun Zhang', 'Fairway_Streak': 20, 'Year': 2018},
#  {'Player': 'George McNeill', 'Fairway_Streak': 20, 'Year': 2018},
#  {'Player': 'Ollie Schniederjans', 'Fairway_Streak': 19, 'Year': 2018},
#  {'Player': 'Austin Cook', 'Fairway_Streak': 19, 'Year': 2018},
#  {'Player': 'Bud Cauley', 'Fairway_Streak': 19, 'Year': 2018},
#  {'Player': 'Emiliano Grillo', 'Fairway_Streak': 19, 'Year': 2018},
#  {'Player': 'Brian Stuard', 'Fairway_Streak': 19, 'Year': 2018},
#  {'Player': 'Jim Herman', 'Fairway_Streak': 19, 'Year': 2018},
#  {'Player': 'Branden Grace', 'Fairway_Streak': 19, 'Year': 2018},
 'Fairway_Streak': 6, 'Year': 2018},
#  {'Player': 'Robert Allenby', 'Fairway_Streak': 6, 'Year': 2018},
#  {'Player': 'Mike Weir', 'Fairway_Streak': 6, 'Year': 2018},
#  {'Player': 'Tiger Woods', 'Fairway_Streak': 6, 'Year': 2018},
#  {'Player': 'Paul Goydos', 'Fairway_Streak': 6, 'Year': 2018},
#  {'Player': 'Lee Janzen', 'Fairway_Streak': 6, 'Year': 2018},
#  {'Player': 'Bob Estes', 'Fairway_Streak': 6, 'Year': 2018},
#  {'Player': 'Keith Clearwater', 'Fairway_Streak': 6, 'Year': 2018},
#  {'Player': 'Mark Brooks', 'Fairway_Streak': 6, 'Year': 2018},
#  {'Player': 'Andrew Filbert', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Ben Wolcott', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Braden Thornberry', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Andrew Novak', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Zach Cabra', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Wyndham Clark', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Bobby Wyatt', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Jordan Niebrugge', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Augusto Núñez', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Alexander Levy', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Chris Paisley', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Satoshi Kodaira', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Bobby Gates', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Rafael Campos', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Richard Lee', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Dan McCarthy', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Martin Kaymer', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Marc Turnesa', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Rod Perry', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Andres Romero', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Steven Bowditch', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Graeme Storm', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Jason Gore', 'Fairway_Streak': 5, 'Year': 2018},
#  {'Player': 'Ashley Hall', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Curtis Luck', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Jim Knous', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Yanwei Liu', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Andrew Loupe', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Anthony Paolucci', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Richard Lee', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Eric Dugas', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Ryan Fox', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Mike Hendry', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Andres Gonzales', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'John Mallinger', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Brett Rumford', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'John Rollins', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Craig Barlow', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'David Duval', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Gunn Yang', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Kevin Dougherty', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Dino Giacomazzi', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Jimmy Stanger', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Ross Bell', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Ty Strafaci', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Tony Romo', 'Fairway_Streak': 4, 'Year': 2018},
#  {'Player': 'Steve Allan', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Phil Schmitt', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Adam Bland', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Javier Colomo', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Danny Willett', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Jhared Hack', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Yi Cao', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Jamie Sadlowski', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Nyasha Mauchaza', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Willy Pumarol', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Derek Barron', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Donny Lee', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Scottie Scheffler', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Tyler Torano', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Kurt Kitayama', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Grady Brame', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'JJ Wood', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Charles Reiter', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Tyler Ota', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Norman Xiong', 'Fairway_Streak': 3, 'Year': 2018},
#  {'Player': 'Vinnie Poncino', 'Fairway_Streak': 2, 'Year': 2018},
#  {'Player': 'Tatsuya Kodai', 'Fairway_Streak': 2, 'Year': 2018},
#  {'Player': 'Hyung-Sung Kim', 'Fairway_Streak': 2, 'Year': 2018},
#  {'Player': 'Heath Slocum', 'Fairway_Streak': 25, 'Year': 2010},
#  {'Player': 'Brian Gay', 'Fairway_Streak': 23, 'Year': 2010},
#  {'Player': 'Jason Dufner', 'Fairway_Streak': 22, 'Year': 2010},
#  {'Player': 'Chez Reavie', 'Fairway_Streak': 21, 'Year': 2010},
#  {'Player': 'Bill Haas', 'Fairway_Streak': 21, 'Year': 2010},
#  {'Player': 'Tim Clark', 'Fairway_Streak': 21, 'Year': 2010},
#  {'Player': 'Chris DiMarco', 'Fairway_Streak': 21, 'Year': 2010},
#  {'Player': 'Tom Gillis', 'Fairway_Streak': 20, 'Year': 2010},
#  {'Player': 'Jay Williamson', 'Fairway_Streak': 20, 'Year': 2010},
#  {'Player': 'Billy Mayfair', 'Fairway_Streak': 20, 'Year': 2010},
#  {'Player': 'Carl Pettersson', 'Fairway_Streak': 20, 'Year': 2010},
#  {'Player': 'Kevin Na', 'Fairway_Streak': 20, 'Year': 2010},
#  {'Player': 'Richard Johnson', 'Fairway_Streak': 19, 'Year': 2010},
#  {'Player': 'Corey Pavin', 'Fairway_Streak': 19, 'Year': 2010},
#  {'Player': 'Steve Lowery', 'Fairway_Streak': 18, 'Year': 2010},
#  {'Player': 'Tom Lehman', 'Fairway_Streak': 18, 'Year': 2010},
#  {'Player': 'Paul Goydos', 'Fairway_Streak': 18, 'Year': 2010},
#  {'Player': 'Justin Bolli', 'Fairway_Streak': 18, 'Year': 2010},
#  {'Player': 'Luke Donald', 'Fairway_Streak': 18, 'Year': 2010},
#  {'Player': 'Chris Baryla', 'Fairway_Streak': 18, 'Year': 2010},
#  {'Player': 'Josh Teater', 'Fairway_Streak': 17, 'Year': 2010},
#  {'Player': 'Nicholas Thompson', 'Fairway_Streak': 17, 'Year': 2010},
#  {'Player': 'Jason Bohn', 'Fairway_Streak': 17, 'Year': 2010},
#  {'Player': 'Marc Turnesa', 'Fairway_Streak': 17, 'Year': 2010},
#  {'Player': 'Michael Allen', 'Fairway_Streak': 17, 'Year': 2010},
#  {'Player': 'Kevin Johnson', 'Fairway_Streak': 17, 'Year': 2010},
#  {'Player': 'Omar Uresti', 'Fairway_Streak': 17, 'Year': 2010},
#  {'Player': 'J.P. Hayes', 'Fairway_Streak': 17, 'Year': 2010},
#  {'Player': 'Bob Estes', 'Fairway_Streak': 17, 'Year': 2010},
#  {'Player': 'David Toms', 'Fairway_Streak': 17, 'Year': 2010},
#  {'Player': 'Scott Verplank', 'Fairway_Streak': 17, 'Year': 2010},
#  {'Player': 'Chad Campbell', 'Fairway_Streak': 17, 'Year': 2010},
#  {'Player': 'Garrett Willis', 'Fairway_Streak': 17, 'Year': 2010},
#  {'Player': 'Rod Pampling', 'Fairway_Streak': 17, 'Year': 2010},
#  {'Player': 'Mathew Goggin', 'Fairway_Streak': 16, 'Year': 2010},
#  {'Player': 'Matt Kuchar', 'Fairway_Streak': 16, 'Year': 2010},
#  {'Player': 'Vaughn Taylor', 'Fairway_Streak': 16, 'Year': 2010},
#  {'Player': 'Freddie Jacobson', 'Fairway_Streak': 16, 'Year': 2010},
#  {'Player': 'David Duval', 'Fairway_Streak': 16, 'Year': 2010},
#  {'Player': 'Justin Leonard', 'Fairway_Streak': 16, 'Year': 2010},
#  {'Player': 'Jeff Maggert', 'Fairway_Streak': 16, 'Year': 2010},
#  {'Player': 'Boo Weekley', 'Fairway_Streak': 16, 'Year': 2010},
#  {'Player': 'Michael Connell', 'Fairway_Streak': 16, 'Year': 2010},
#  {'Player': 'Matt Every', 'Fairway_Streak': 16, 'Year': 2010},
#  {'Player': 'John Merrick', 'Fairway_Streak': 16, 'Year': 2010},
#  {'Player': 'Troy Matteson', 'Fairway_Streak': 16, 'Year': 2010},
#  {'Player': 'John Mallinger', 'Fairway_Streak': 15, 'Year': 2010},
#  {'Player': 'Blake Adams', 'Fairway_Streak': 15, 'Year': 2010},
#  {'Player': 'Alex Prugh', 'Fairway_Streak': 15, 'Year': 2010},
#  {'Player': 'Gregor Main', 'Fairway_Streak': 15, 'Year': 2010},
#  {'Player': 'Bubba Watson', 'Fairway_Streak': 15, 'Year': 2010},
#  {'Player': 'Mark Brooks', 'Fairway_Streak': 15, 'Year': 2010},
#  {'Player': 'Steve Elkington', 'Fairway_Streak': 15, 'Year': 2010},
#  {'Player': "Nick O'Hern", 'Fairway_Streak': 15, 'Year': 2010},
#  {'Player': 'John Rollins', 'Fairway_Streak': 15, 'Year': 2010},
#  {'Player': 'Henrik Bjornstad', 'Fairway_Streak': 15, 'Year': 2010},
#  {'Player': 'Alex Cejka', 'Fairway_Streak': 15, 'Year': 2010},
#  {'Player': 'Charlie Wi', 'Fairway_Streak': 14, 'Year': 2010},
#  {'Player': 'Greg Owen', 'Fairway_Streak': 14, 'Year': 2010},
#  {'Player': 'Chris Riley', 'Fairway_Streak': 14, 'Year': 2010},
#  {'Player': 'Jason Gore', 'Fairway_Streak': 14, 'Year': 2010},
#  {'Player': 'Ted Purdy', 'Fairway_Streak': 14, 'Year': 2010},
#  {'Player': 'Henrik Stenson', 'Fairway_Streak': 14, 'Year': 2010},
#  {'Player': 'Vijay Singh', 'Fairway_Streak': 14, 'Year': 2010},
#  {'Player': 'Jim Furyk', 'Fairway_Streak': 14, 'Year': 2010},
#  {'Player': 'Chris Wilson', 'Fairway_Streak': 14, 'Year': 2010},
#  {'Player': 'Kevin Stadler', 'Fairway_Streak': 14, 'Year': 2010},
#  {'Player': 'Ryan Moore', 'Fairway_Streak': 14, 'Year': 2010},
#  {'Player': 'Pat Perez', 'Fairway_Streak': 14, 'Year': 2010},
#  {'Player': 'Billy Horschel', 'Fairway_Streak': 14, 'Year': 2010},
#  {'Player': 'Philip Francis', 'Fairway_Streak': 14, 'Year': 2010},
#  {'Player': 'Johnson Wagner', 'Fairway_Streak': 13, 'Year': 2010},
#  {'Player': 'Rickie Fowler', 'Fairway_Streak': 13, 'Year': 2010},
#  {'Player': "Sean O'Hair", 'Fairway_Streak': 13, 'Year': 2010},
#  {'Player': 'Simon Dyson', 'Fairway_Streak': 13, 'Year': 2010},
#  {'Player': 'Hunter Mahan', 'Fairway_Streak': 13, 'Year': 2010},
#  {'Player': 'Woody Austin', 'Fairway_Streak': 13, 'Year': 2010},
#  {'Player': 'Kenny Perry', 'Fairway_Streak': 13, 'Year': 2010},
#  {'Player': 'Tim Petrovic', 'Fairway_Streak': 13, 'Year': 2010},
#  {'Player': 'Rocco Mediate', 'Fairway_Streak': 13, 'Year': 2010},
#  {'Player': 'Cameron Percy', 'Fairway_Streak': 13, 'Year': 2010},
#  {'Player': 'Justin Rose', 'Fairway_Streak': 13, 'Year': 2010},
#  {'Player': 'Cameron Beckman', 'Fairway_Streak': 13, 'Year': 2010},
#  {'Player': 'Padraig Harrington', 'Fairway_Streak': 13, 'Year': 2010},
#  {'Player': 'Daniel Chopra', 'Fairway_Streak': 13, 'Year': 2010},
#  {'Player': 'Greg Chalmers', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Ben Curtis', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Stephen Ames', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Brad Faxon', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Mike Weir', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Robert Allenby', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Joe Durant', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Steve Flesch', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Ernie Els', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Y.E. Yang', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Zach Johnson', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Matt Jones', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Chad Collins', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Jeff Quinney', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Troy Merritt', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Webb Simpson', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Jeff Overton', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Kris Blanks', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Derek Lamely', 'Fairway_Streak': 12, 'Year': 2010},
#  {'Player': 'Brandt Snedeker', 'Fairway_Streak': 11, 'Year': 2010},
#  {'Player': 'Steve Marino', 'Fairway_Streak': 11, 'Year': 2010},
#  {'Player': 'Rory McIlroy', 'Fairway_Streak': 11, 'Year': 2010},
#  {'Player': 'Nick Watney', 'Fairway_Streak': 11, 'Year': 2010},
#  {'Player': 'Kevin Streelman', 'Fairway_Streak': 11, 'Year': 2010},
#  {'Player': 'Graham DeLaet', 'Fairway_Streak': 11, 'Year': 2010},
#  {'Player': 'Chris Stroud', 'Fairway_Streak': 11, 'Year': 2010},
#  {'Player': 'Tim Wilkinson', 'Fairway_Streak': 11, 'Year': 2010},
#  {'Player': 'Ian Poulter', 'Fairway_Streak': 11, 'Year': 2010},
#  {'Player': 'Bryce Molder', 'Fairway_Streak': 11, 'Year': 2010},
#  {'Player': 'Rory Sabbatini', 'Fairway_Streak': 11, 'Year': 2010},
#  {'Player': 'Brendon de Jonge', 'Fairway_Streak': 11, 'Year': 2010},
#  {'Player': 'K.J. Choi', 'Fairway_Streak': 11, 'Year': 2010},
#  {'Player': 'Frank Lickliter II', 'Fairway_Streak': 11, 'Year': 2010},
#  {'Player': 'Chris Couch', 'Fairway_Streak': 11, 'Year': 2010},
#  {'Player': 'Scott McCarron', 'Fairway_Streak': 11, 'Year': 2010},
#  {'Player': 'Bob Heintz', 'Fairway_Streak': 11, 'Year': 2010},
#  {'Player': '
 'Fairway_Streak': 6, 'Year': 2010},
#  {'Player': 'Ross Fisher', 'Fairway_Streak': 6, 'Year': 2010},
#  {'Player': 'Kevin Chappell', 'Fairway_Streak': 5, 'Year': 2010},
#  {'Player': 'Benjamin Fox', 'Fairway_Streak': 5, 'Year': 2010},
#  {'Player': 'Estanislao Guerrero', 'Fairway_Streak': 5, 'Year': 2010},
#  {'Player': 'Joshua Wooding', 'Fairway_Streak': 5, 'Year': 2010},
#  {'Player': 'William McGirt', 'Fairway_Streak': 5, 'Year': 2010},
#  {'Player': 'Soren Hansen', 'Fairway_Streak': 5, 'Year': 2010},
#  {'Player': 'Perry Moss', 'Fairway_Streak': 5, 'Year': 2010},
#  {'Player': 'Todd Hamilton', 'Fairway_Streak': 5, 'Year': 2010},
#  {'Player': 'John Huston', 'Fairway_Streak': 5, 'Year': 2010},
#  {'Player': 'Ben Bates', 'Fairway_Streak': 5, 'Year': 2010},
#  {'Player': 'Andrew Magee', 'Fairway_Streak': 5, 'Year': 2010},
#  {'Player': 'Dean Wilson', 'Fairway_Streak': 5, 'Year': 2010},
#  {'Player': 'Matt Bettencourt', 'Fairway_Streak': 5, 'Year': 2010},
#  {'Player': 'Miguel Angel Jiménez', 'Fairway_Streak': 5, 'Year': 2010},
#  {'Player': 'Robert Karlsson', 'Fairway_Streak': 5, 'Year': 2010},
#  {'Player': 'Shigeki Maruyama', 'Fairway_Streak': 4, 'Year': 2010},
#  {'Player': 'Tim Herron', 'Fairway_Streak': 4, 'Year': 2010},
#  {'Player': 'Patrick Moore', 'Fairway_Streak': 4, 'Year': 2010},
#  {'Player': 'Jeev Milkha Singh', 'Fairway_Streak': 4, 'Year': 2010},
#  {'Player': 'Michael Campbell', 'Fairway_Streak': 4, 'Year': 2010},
#  {'Player': 'Dean Vomacka', 'Fairway_Streak': 4, 'Year': 2010},
#  {'Player': 'Daisuke Maruyama', 'Fairway_Streak': 4, 'Year': 2010},
#  {'Player': 'Jerry Pate', 'Fairway_Streak': 4, 'Year': 2010},
#  {'Player': 'Tim Thelen', 'Fairway_Streak': 4, 'Year': 2010},
#  {'Player': 'Jim Carter', 'Fairway_Streak': 4, 'Year': 2010},
#  {'Player': 'Greg Casagranda', 'Fairway_Streak': 4, 'Year': 2010},
#  {'Player': 'Gonzalo Fernandez-Castaño', 'Fairway_Streak': 4, 'Year': 2010},
#  {'Player': 'Ryuichi Oda', 'Fairway_Streak': 4, 'Year': 2010},
#  {'Player': 'Rod Perry', 'Fairway_Streak': 4, 'Year': 2010},
#  {'Player': 'Andrew Svoboda', 'Fairway_Streak': 4, 'Year': 2010},
#  {'Player': 'Blake Trimble', 'Fairway_Streak': 4, 'Year': 2010},
#  {'Player': 'Michael Putnam', 'Fairway_Streak': 4, 'Year': 2010},
#  {'Player': 'Tadd Fujikawa', 'Fairway_Streak': 3, 'Year': 2010},
#  {'Player': 'T.J. Kua', 'Fairway_Streak': 3, 'Year': 2010},
#  {'Player': 'Nick Mason', 'Fairway_Streak': 3, 'Year': 2010},
#  {'Player': 'Ryan Garrity', 'Fairway_Streak': 3, 'Year': 2010},
#  {'Player': 'Andy Matthews', 'Fairway_Streak': 3, 'Year': 2010},
#  {'Player': 'Kaname Yokoo', 'Fairway_Streak': 3, 'Year': 2010},
#  {'Player': 'Kevin Hayashi', 'Fairway_Streak': 2, 'Year': 2010},
#  {'Player': 'Jeff Templeton', 'Fairway_Streak': 2, 'Year': 2010},
#  {'Player': 'Gunner Wiebe', 'Fairway_Streak': 2, 'Year': 2010},
#  {'Player': 'Nathan Tyler', 'Fairway_Streak': 2, 'Year': 2010}]

# %% [markdown]
# # Function for Most Consecutive Fairways Hit

# %%
def get_consec_greens(urls):
    List_stats = []
    for url in urls:
        soup = BS((requests.get(url)).content, 'html.parser')
        page = soup.find('tbody')
        for row in page.find_all('tr'):
            Stats = {}
            name = (row.find('td', class_= 'player-name').get_text())
            name = name.split('\n')
            Stats['Player'] = name[1]
            Stats["Fairway_Streak"] = int(row.find('td', class_= 'player-name').find_next('td').get_text())
            Stats['Year'] = int(url[56:60])
            List_stats.append(Stats)
    return List_stats

# %% [markdown]
# # Function for Most Consectuive Greens Hit In Reg YTD

# %%
def get_consec_greens(urls):
    List_stats = []
    for url in urls:
        soup = BS((requests.get(url)).content, 'html.parser')
        page = soup.find('tbody')
        for row in page.find_all('tr'):
            Stats = {}
            name = (row.find('td', class_= 'player-name').get_text())
            name = name.split('\n')
            Stats['Player'] = name[1]
            Stats["Highest_Green_Streak"] = int(row.find('td', class_= 'player-name').find_next('td').get_text())
            Stats['Year'] = int(url[56:60])
            List_stats.append(Stats)
    return List_stats

# %% [markdown]
# # Function for TOP 10s YTD

# %%
def get_top10s(urls):
    List_stats = []
    for url in urls:
        soup = BS((requests.get(url)).content, 'html.parser')
        page = soup.find('tbody')
        for row in page.find_all('tr'):
            Stats = {}
            name = (row.find('td', class_= 'player-name').get_text())
            name = name.split('\n')
            Stats['Player'] = name[1]
            Stats["Top_10's"] = float(row.find('td', class_= 'hidden-small hidden-medium').find_next().get_text())
            Stats['Year'] = int(url[56:60])
            List_stats.append(Stats)
    return List_stats

# %% [markdown]
# # Function for Putting Average YTD

# %%
def get_putting_avg(urls):
    List_stats = []
    for url in urls:
        soup = BS((requests.get(url)).content, 'html.parser')
        page = soup.find('tbody')
        for row in page.find_all('tr'):
            Stats = {}
            name = (row.find('td', class_= 'player-name').get_text())
            name = name.split('\n')
            Stats['Player'] = name[1]
            Stats['Putting_Average'] = float(row.find('td', class_= 'hidden-small hidden-medium').find_next().get_text())
            Stats['Year'] = int(url[56:60])
            List_stats.append(Stats)
    return List_stats

# %% [markdown]
# # Function for Greens Hit Percents YTD

# %%
def get_greens_hit(urls):
    List_stats = []
    for url in urls:
        soup = BS((requests.get(url)).content, 'html.parser')
        page = soup.find('tbody')
        for row in page.find_all('tr'):
            Stats = {}
            name = (row.find('td', class_= 'player-name').get_text())
            name = name.split('\n')
            Stats['Player'] = name[1]
            Stats['Percent_Greens_Hit'] = float(row.find('td', class_= 'hidden-small hidden-medium').find_next().get_text())
            Stats['Year'] = int(url[56:60])
            List_stats.append(Stats)
    return List_stats

# %% [markdown]
# # Function for Grabbing Percent_Fairway_Hit YTD

# %%
def get_fairway_stats(urls):
    List_stats = []
    for url in urls:
        soup = BS((requests.get(url)).content, 'html.parser')
        page = soup.find('tbody')
        for row in page.find_all('tr'):
            Stats = {}
            name = (row.find('td', class_= 'player-name').get_text())
            name = name.split('\n')
            Stats['Player'] = name[1]
            Stats['Percent_Fairway_Hit'] = float(row.find('td', class_= 'hidden-small hidden-medium').find_next().get_text())
            Stats['Year'] = int(url[56:60])
            List_stats.append(Stats)
    return List_stats

# %% [markdown]
# # Function For Grabbing Driving Distance Stats YTD

# %%
def get_driving_stats(urls):
    List_stats = []
    for url in urls:
        soup = BS((requests.get(url)).content, 'html.parser')
        page = soup.find('tbody')
        for row in page.find_all('tr'):
            Stats = {}
            name = (row.find('td', class_= 'player-name').get_text())
            name = name.split('\n')
            rank = (row.find('td')).get_text().strip().strip('T')
            rank = rank.split('\n')
            Stats['Player'] = name[1]
            Stats['Driving_Rank'] = rank[0]
            Stats['Average_Drive_Distance'] = float(row.find('td', class_= 'hidden-small hidden-medium').find_next().get_text())
            Stats['Year'] = int(url[56:60])
            List_stats.append(Stats)
    return List_stats

# %% [markdown]
# # FUNCTION THAT GRABS MASTERS LEADERBORD RANK

# %%
def Masters_Rank(year):
#     Years = [x for x in range(1980,2020)]
#     List_stats = []
#     for year in Years:
        url ='https://www.pgatour.com/tournaments/masters-tournament/past-results.2010.html'.format(year)
        soup = BS((requests.get(url)).content, 'html.parser')
        page = soup.find('tbody')
        for row in page.find_all('td'):

#         for row in page.find('tr'):
#             Stats = {}
#             Stats['Player'] = row.find('td', class_ ='cell').get_text()
#             Stats['Rank'] = row.find('td').get_text()
#             List_stats.append(Stats)
#     return List_stats
# Out:
#   File "<ipython-input-903-324ce2c10ef3>", line 15
#     #     return List_stats
#                            ^
# SyntaxError: unexpected EOF while parsing

# %%
def Masters_Rank(year):
        money = []
        url ='https://www.pgatour.com/tournaments/masters-tournament/past-results.1991.html'
        soup = BS((requests.get(url)).content, 'html.parser')
        for item in soup.find_all("div"):
              money.append(item.find_all('tr'))
        return money

# %%
Masters_Rank(2018)
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [<tr>
#   <td><span class="icon-alert"></span></td>
#   <td>
#   <p>It appears your browser may be outdated. For the best website experience, we recommend updating your browser.
#
#                                   <a class="message-button" href="http://windows.microsoft.com/en-us/internet-explorer/download-ie">
#                                       learn more</a>
#   </p>
#   </td>
#   <td><span class="close-message"></span></td>
#   </tr>],
#  [<tr>
#   <td><span class="icon-alert"></span></td>
#   <td>
#   <p>It appears your browser may be outdated. For the best website experience, we recommend updating your browser.
#
#                                   <a class="message-button" href="http://windows.microsoft.com/en-us/internet-explorer/download-ie">
#                                       learn more</a>
#   </p>
#   </td>
#   <td><span class="close-message"></span></td>
#   </tr>],
#  [<tr>
#   <td><span class="icon-alert"></span></td>
#   <td>
#   <p>It appears your browser may be outdated. For the best website experience, we recommend updating your browser.
#
#                                   <a class="message-button" href="http://windows.microsoft.com/en-us/internet-explorer/download-ie">
#                                       learn more</a>
#   </p>
#   </td>
#   <td><span class="close-message"></span></td>
#   </tr>],
#  [<tr>
#   <td><span class="icon-alert"></span></td>
#   <td>
#   <p>It appears your browser may be outdated. For the best website experience, we recommend updating your browser.
#
#                                   <a class="message-button" href="http://windows.microsoft.com/en-us/internet-explorer/download-ie">
#                                       learn more</a>
#   </p>
#   </td>
#   <td><span class="close-message"></span></td>
#   </tr>],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %% [markdown]
# # URLs 1980-2019 For Each Stat Leading Up To Masters Tournament

# %%
Driving_Distance_urls = ['https://www.pgatour.com/content/pgatour/stats/stat.101.y1980.eoff.t013.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1981.eoff.t013.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1982.eoff.t013.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1983.eoff.t013.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1984.eoff.t013.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1985.eoff.t013.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1986.eoff.t054.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1987.eoff.t054.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1988.eoff.t054.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1989.eoff.t054.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1990.eoff.t054.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1991.eoff.t054.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1992.eoff.t054.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1993.eoff.t054.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1994.eoff.t018.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1995.eoff.t018.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1996.eoff.t022.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1997.eoff.t018.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1998.eoff.t018.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y1999.eoff.t022.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2000.eoff.t022.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2001.eoff.t022.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2002.eoff.t022.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2003.eoff.t022.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2004.eoff.t022.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2005.eoff.t022.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2006.eoff.t022.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2007.eoff.t020.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2008.eoff.t020.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2009.eoff.t020.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2010.eoff.t020.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2011.eoff.t020.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2012.eoff.t020.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2013.eoff.t041.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2014.eoff.t020.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2015.eoff.t020.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2016.eoff.t020.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2017.eoff.t020.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2018.eoff.t020.html',
'https://www.pgatour.com/content/pgatour/stats/stat.101.y2019.eoff.t041.html']

# %%
Fairway_Percent_URLs = []
for url in Driving_Distance_urls:
    Fairway_Percent_URLs.append(url.replace('101', '102'))

# %%
Greens_Hit_URLs = []
for url in Driving_Distance_urls:
    Greens_Hit_URLs.append(url.replace('101', '103'))

# %%
Putting_Average_URLs = []
for url in Driving_Distance_urls:
    Putting_Average_URLs.append(url.replace('101', '104'))

# %%
Top_10_URLs = []
for url in Driving_Distance_urls:
    Top_10_URLs.append(url.replace('101', '138'))

# %%
Consecutive_Greens_URLS = []
for url in Driving_Distance_urls:
    Consecutive_Greens_URLS.append(url.replace('101', '298'))

# %%
Consecutive_Fairways_URLs = []
for url in Driving_Distance_urls:
    Consecutive_Fairways_URLs.append(url.replace('101', '297'))

# %% [markdown]
# # WORKING

# %%
dict1 = [{'Player': 'Findlay Bowditch', 'Stat1': 0, 'Year' : 2018},
{'Player': 'Sarah Bowditch', 'Stat1': 1, 'Year' : 2018},
{'Player': 'William Bowditch', 'Stat1': 1, 'Year' : 2018},
{'Player': 'Findlay Bowditch', 'Stat1': 1, 'Year' : 2017},
{'Player': 'Sarah Bowditch', 'Stat1': 0, 'Year' : 2017},
{'Player': 'William Bowditch', 'Stat1': 1, 'Year' : 2017}]

dict2 = [{'Player': 'Findlay Bowditch', 'Stat4': 40, 'Year' : 2018},
{'Player': 'Sarah Bowditch', 'Stat4': 30, 'Year' : 2018},
{'Player': 'William Bowditch', 'Stat4': 90, 'Year' : 2018},
{'Player': 'Findlay Bowditch', 'Stat4': 40, 'Year' : 2017},
{'Player': 'Sarah Bowditch', 'Stat4': 30, 'Year' : 2017},
{'Player': 'William Bowditch', 'Stat4': 90, 'Year' : 2017},
{'Player': 'John Adams', 'Stat4': 11, 'Year': 2017}]

dict4 = [{'Player': 'Bobby Bowditch', 'Stat6': 90, 'Year' : 2017},
{'Player': 'Peter Pickle', 'Stat5': 11, 'Year': 2017}]

# %%
for i in dict1:
# Out:
#   File "<ipython-input-14-eca02096cf03>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
import pandas as pd

# %%
df = pd.DataFrame(dict1)

# %%
df2 = pd.DataFrame(dict2)

# %%
df4 = pd.DataFrame(dict4)

# %%
df3 = pd.merge(df,df2, how = 'outer')

# %%
df3
# Out:
#              Player  Stat1  Year  Stat4
# 0  Findlay Bowditch    0.0  2018     40
# 1    Sarah Bowditch    1.0  2018     30
# 2  William Bowditch    1.0  2018     90
# 3  Findlay Bowditch    1.0  2017     40
# 4    Sarah Bowditch    0.0  2017     30
# 5  William Bowditch    1.0  2017     90
# 6        John Adams    NaN  2017     11

# %%
df5 = pd.merge(df3,df4, how = 'outer')

# %%
df5
# Out:
#              Player  Stat1  Year  Stat4  Stat6  Stat5
# 0  Findlay Bowditch   22.0  2018   40.0    NaN    NaN
# 1    Sarah Bowditch   18.0  2018   30.0    NaN    NaN
# 2  William Bowditch   40.0  2018   90.0    NaN    NaN
# 3  Findlay Bowditch   44.0  2017   40.0    NaN    NaN
# 4    Sarah Bowditch   16.0  2017   30.0    NaN    NaN
# 5  William Bowditch   34.0  2017   90.0    NaN    NaN
# 6        John Adams    NaN  2017   11.0    NaN    NaN
# 7    Bobby Bowditch    NaN  2017    NaN   90.0    NaN
# 8      Peter Pickle    NaN  2017    NaN    NaN   11.0

# %%
y = df5.groupby('Player')

# %%
y
